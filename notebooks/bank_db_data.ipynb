# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
bank_marketing = fetch_ucirepo(id=222) 
  
# data (as pandas dataframes) 
X = bank_marketing.data.features 
y = bank_marketing.data.targets 
  
# metadata 
print(bank_marketing.metadata) 
  
# variable information 
print(bank_marketing.variables)
# Out:
# Running cells with '.venv (3.12.4) (Python 3.12.4)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"/Users/rogerdefez/Documents/Cursos i Llibres/BootCamp IT Academy/04_Simulador/Individual_Simulator/.venv/bin/python" -m pip install ipykernel -U --force-reinstall'
